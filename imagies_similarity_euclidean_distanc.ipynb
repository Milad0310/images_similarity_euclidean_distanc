# %%
#import library
import cv2
import matplotlib.pyplot as plt

# %%
#read img & convert it gray scale & calc it's hist
main_img = cv2.imread("data14.jpg")
rgb_img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
gry_main_img = cv2.cvtColor(main_img, cv2.COLOR_BGR2GRAY)
hist = cv2.calcHist(gry_main_img,[0],None,[256], [0, 256])

# %%
imgplot = plt.imshow(rgb_img)
plt.show()

# %%
#read img & convert it gray scale & calc it's hist
test_img1 = cv2.imread("test11.jpg")
rgb_img1 = cv2.cvtColor(test_img1, cv2.COLOR_BGR2RGB)
gry_test_img1 = cv2.cvtColor(main_img, cv2.COLOR_BGR2GRAY)
hist1 = cv2.calcHist(gry_main_img,[0],None,[256], [0, 256])

# %%
imgplot = plt.imshow(rgb_img1)
plt.show()

# %%
#read img & convert it gray scale & calc it's hist
test_img2 = cv2.imread("data22.jpg")
rgb_img2 = cv2.cvtColor(test_img2, cv2.COLOR_BGR2RGB)
gry_test_img2= cv2.cvtColor(main_img, cv2.COLOR_BGR2GRAY)
hist2 = cv2.calcHist(gry_main_img,[0],None,[256], [0, 256])

# %%
imgplot = plt.imshow(test_img2)
plt.show()

# %%
#calc img's euclidean distanc 
c1, c2 = 0, 0
for i in range (len(hist)):
    c1 += (hist[i] - hist1[i])**2
c1 = c1**0.5

# %%
#calc img's euclidean distanc 
for i in range (len(hist)):
    c2 += (hist[i] - hist2[i])**2
c2 = c2**0.5

# %%
if c1 > c2:
    print('test img1 is similar to main img than test img2')
else:
    print('test img1 is similar to main img than test img2')
# Out:
# test img1 is similar to main img than test img2
